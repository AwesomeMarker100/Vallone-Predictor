# %%
import openpyxl
import pandas as pd
import numpy as np

election_results_2020_path = "C:\Users\cleme\Downloads\federalelections2020.xlsx"

house_results = pd.read_excel(election_results_2020_path, sheet_name="13. US House Results by State")
president_results = pd.read_excel(election_results_2020_path, sheet_name="9. 2020 Pres General Results")


republican_winners = house_results.loc[(house_results["PARTY"] == "R") & (house_results["GE WINNER INDICATOR"] == "W")]
democrat_winners = house_results.loc[(house_results["PARTY"] == "D") & (house_results["GE WINNER INDICATOR"] == "W")]

print(len(republican_winners) + len(democrat_winners))

# %%
import pandas as pd
import numpy as np

county_census = r'C:\Users\mvall\Downloads\DECENNIALDP2020.DP1-Data.csv'

cd = pd.read_csv(county_census, header=1)

#'Geographic Area Name'
#'Count!!SEX AND AGE!!Total population'
#'Count!!RACE!!Total population!!One Race!!White'
#'Count!!RACE!!Total population!!One Race!!Black or African American'
#'Count!!RACE!!Total population!!One Race!!Asian'
#'Count!!HISPANIC OR LATINO!!Total population!!Hispanic or Latino (of any race)'

county = cd['Geographic Area Name']
pop = cd['Count!!SEX AND AGE!!Total population']
wnum = cd['Count!!RACE!!Total population!!One Race!!White']
bnum = cd['Count!!RACE!!Total population!!One Race!!Black or African American']
anum = cd['Count!!RACE!!Total population!!One Race!!Asian']
hnum = cd['Count!!HISPANIC OR LATINO!!Total population!!Hispanic or Latino (of any race)']
wdiv = cd['Count!!RACE!!Total population!!One Race!!White']/cd['Count!!SEX AND AGE!!Total population']
bdiv = cd['Count!!RACE!!Total population!!One Race!!Black or African American']/cd['Count!!SEX AND AGE!!Total population']
adiv = cd['Count!!RACE!!Total population!!One Race!!Asian']/cd['Count!!SEX AND AGE!!Total population']
hdiv = cd['Count!!HISPANIC OR LATINO!!Total population!!Hispanic or Latino (of any race)']/cd['Count!!SEX AND AGE!!Total population']

wd = pd.concat([county, pop, wnum, wdiv, bnum, bdiv, anum, adiv, hnum, hdiv], axis=1)

wd.to_csv(r'C:\Users\mvall\Documents\div.csv', header=['County', 'Population', 'White Population','% White', 'Black Population', '% Black', 'Asian Population', '% Asian', 'Hispanic Population', '% Hispanic'])

# %%
import geopandas as gp
import pandas as pd
import numpy as np

# %%
import openpyxl
import pandas as pd
import numpy as np

# %%
import gdown
import os.path

if not os.path.exists("Geospatial Election Data"):
    gdown.download_folder(id="1GGn98K002bbEBxbmHWE1PpZ1MrS3Em6r")

folder = os.listdir("Geospatial Election Data")

links = []

for file in folder:
    links.append("Geospatial Election Data/" + file)

print(links)
# Out:
# ['Geospatial Election Data/age_and_sex_data_by_county.csv', 'Geospatial Election Data/countypres_2000-2020.csv', 'Geospatial Election Data/county_borders.geojson', 'Geospatial Election Data/federalelections2020.xlsx', 'Geospatial Election Data/Past Election Data', 'Geospatial Election Data/race_data_by_county.csv']

# %%
import pandas as pd
import geopandas as gpd
import numpy as np

age_and_sex_data_by_county_path = links[0]
race_data_by_county_path = links[5]
county_borders_path = links[2]

cgeo = gpd.read_file("county_geojson.geojson")
shii = pd.read_excel(links[3], sheet_name="9. 2020 Pres General Results")
countyd = pd.read_csv('Geospatial Election Data\countypres_2000-2020.csv')


shii.drop(columns="FEC ID")


cgeo["STATE"] = cgeo["STATE"].astype(str)

for idx, row in cgeo.iterrows():

    split_data = str(row["NAME_y"]).split(",")

    try:
        cgeo.at[idx, "STATE"] = split_data[1].strip()
    except:
        pass

countyd.county_name.unique()

countyu = countyd.county_name.unique()

countyd["candidate"] = countyd["candidate"].str.split(', ')




list1 = []
list2 = []



countyg = countyd.groupby(["year", "county_name"])



for x in countyd["candidate"]:
    list1.append(x)

for x in countyd["candidatevotes"]:
    list2.append(x)

print(list2)
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\c'
# <>:11: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\mvall\AppData\Local\Temp\ipykernel_16188\2756871601.py:11: SyntaxWarning: invalid escape sequence '\c'
#   countyd = pd.read_csv('Geospatial Election Data\countypres_2000-2020.csv')
# [4942, 11993, 160, 113, 13997, 40872, 1033, 578, 5188, 5096, 46, 65, 2710, 4273, 52, 66, 4977, 12667, 154, 175, 3395, 1433, 24, 52, 3606, 4127, 36, 34, 15781, 22306, 481, 341, 5616, 6037, 95, 86, 3497, 4154, 77, 95, 4806, 10066, 92, 128, 3707, 3600, 33, 34, 4679, 5988, 33, 52, 2045, 3719, 52, 67, 1664, 3333, 39, 56, 5220, 9938, 155, 121, 10543, 10518, 208, 263, 2783, 2699, 35, 34, 2104, 2382, 34, 47, 4440, 8961, 123, 89, 1934, 2793, 40, 28, 9758, 19157, 282, 328, 4906, 10593, 188, 119, 10967, 7360, 63, 74, 7056, 12827, 175, 227, 6652, 16777, 212, 163, 4523, 6975, 78, 84, 17433, 21087, 435, 393, 3064, 4582, 60, 102, 4793, 6119, 72, 119, 2769, 6588, 97, 105, 3504, 850, 24, 18, 4652, 2984, 43, 52, 2782, 4054, 48, 48, 9412, 22150, 257, 238, 9066, 8475, 184, 181, 129889, 138491, 3393, 1990, 2653, 4470, 57, 69, 13875, 17478, 354, 430, 6296, 5671, 63, 155, 14574, 22433, 895, 362, 8992, 14204, 193, 245, 4557, 1638, 18, 30, 7665, 1091, 31, 44, 48199, 62151, 1885, 1083, 4841, 4690, 40, 37, 4600, 6910, 125, 121, 10381, 17084, 256, 268, 58640, 78162, 1585, 1358, 3741, 5153, 25, 32, 40371, 38827, 677, 453, 16060, 25774, 450, 397, 4020, 1732, 18, 17, 4143, 4306, 39, 52, 4357, 6058, 75, 54, 3094, 4666, 60, 99, 8396, 6198, 109, 72, 6485, 17117, 221, 267, 13183, 47651, 812, 482, 4415, 1629, 20, 24, 11264, 13807, 184, 196, 6183, 9805, 153, 112, 24614, 34003, 1007, 490, 11621, 13486, 264, 270, 3386, 4117, 26, 67, 3444, 1661, 6, 15, 2692, 6413, 88, 125, 13025, 5947, 245, 239, 13360, 18180, 1113, 588, 20280, 17562, 2478, 563, 7700, 9158, 497, 381, 3355, 6007, 144, 158, 1216, 1619, 68, 57, 1769, 2543, 91, 80, 386683, 479967, 22465, 12584, 17470, 24386, 1323, 962, 11794, 12386, 517, 450, 147688, 124579, 12355, 3018, 19650,